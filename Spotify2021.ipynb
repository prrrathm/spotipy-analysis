# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
cid = '5d9494efb79d4abaabc13e9778431f49'
secret = '4d23d535c7fe4e9cadd241ddf58df15e'
client_credentials_manager = SpotifyClientCredentials(
    client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
for i in range(0, 1000, 50):
    track_results = sp.search(q='year:2021', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

# %%
import pandas as pd
track_df = pd.DataFrame({'artist_name': artist_name, 'track_name': track_name,
                        'track_id': track_id, 'track_popularity': track_popularity, 'artist_id': artist_id})
print(track_df.shape)
track_df.head()
# Out:
# (1000, 5)
#      artist_name                                   track_name  \
# 0    Nicky Youre                                      Sunroof
# 1  Morgan Wallen                                Wasted On You
# 2          Drake  Knife Talk (with 21 Savage ft. Project Pat)
# 3          Drake             Wants and Needs (feat. Lil Baby)
# 4     Tory Lanez                             The Color Violet
#
#                  track_id  track_popularity               artist_id
# 0  4h4QlmocP3IuwYEj2j14p8                90  7qmpXeNz2ojlMl2EEfkeLs
# 1  3cBsEDNhFI9E82vPj3kvi3                82  4oUHIQIBe0LHzYfvXNW4QM
# 2  2BcMwX1MPV6ZHP4tUT9uq6                84  3TVXtAsR1Inumwj472S9r4
# 3  65OVbaJR5O1RmwOQx0875b                83  3TVXtAsR1Inumwj472S9r4
# 4  3azJifCSqg9fRij2yKIbWz                84  2jku7tDXc6XoB6MO2hFuqg

# %%
artist_popularity = []
artist_genres = []
artist_followers = []
for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])
    artist_followers.append(artist['followers']['total'])

# %%
track_df = track_df.assign(artist_popularity=artist_popularity,
                           artist_genres=artist_genres, artist_followers=artist_followers)
track_df.head()
# Out:
#      artist_name                                   track_name  \
# 0    Nicky Youre                                      Sunroof
# 1  Morgan Wallen                                Wasted On You
# 2          Drake  Knife Talk (with 21 Savage ft. Project Pat)
# 3          Drake             Wants and Needs (feat. Lil Baby)
# 4     Tory Lanez                             The Color Violet
#
#                  track_id  track_popularity               artist_id  \
# 0  4h4QlmocP3IuwYEj2j14p8                90  7qmpXeNz2ojlMl2EEfkeLs
# 1  3cBsEDNhFI9E82vPj3kvi3                82  4oUHIQIBe0LHzYfvXNW4QM
# 2  2BcMwX1MPV6ZHP4tUT9uq6                84  3TVXtAsR1Inumwj472S9r4
# 3  65OVbaJR5O1RmwOQx0875b                83  3TVXtAsR1Inumwj472S9r4
# 4  3azJifCSqg9fRij2yKIbWz                84  2jku7tDXc6XoB6MO2hFuqg
#
#    artist_popularity                                      artist_genres  \
# 0                 72                                              [pop]
# 1                 83                    [contemporary country, country]
# 2                 95  [canadian hip hop, canadian pop, hip hop, rap,...
# 3                 95  [canadian hip hop, canadian pop, hip hop, rap,...
# 4                 80  [canadian hip hop, canadian trap, melodic rap,...
#
#    artist_followers
# 0             76215
# 1           4229417
# 2          68410744
# 3          68410744
# 4           4753600

# %%
track_features = []
for t_id in track_df['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df = pd.DataFrame(columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
                     'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df = tf_df.append(feat, ignore_index=True)
tf_df.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# ...
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\468735990.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tf_df = tf_df.append(feat, ignore_index=True)
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.768   0.714  10    -5.110    1       0.0401        0.3520
# 1         0.505   0.657  11    -5.240    0       0.0318        0.3730
# 2         0.849   0.424   5    -9.579    0       0.3240        0.0635
# 3         0.578   0.449   1    -6.349    1       0.2860        0.0618
# 4         0.645   0.534   6   -10.800    0       0.0479        0.1570
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.1500    0.842  131.443  audio_features
# 1          0.00107    0.1260    0.252  196.000  audio_features
# 2                0    0.0834    0.153  145.887  audio_features
# 3         0.000002    0.1190    0.100  136.006  audio_features
# 4                0    0.0863    0.463  105.020  audio_features
#
#                        id                                   uri  \
# 0  4h4QlmocP3IuwYEj2j14p8  spotify:track:4h4QlmocP3IuwYEj2j14p8
# 1  3cBsEDNhFI9E82vPj3kvi3  spotify:track:3cBsEDNhFI9E82vPj3kvi3
# 2  2BcMwX1MPV6ZHP4tUT9uq6  spotify:track:2BcMwX1MPV6ZHP4tUT9uq6
# 3  65OVbaJR5O1RmwOQx0875b  spotify:track:65OVbaJR5O1RmwOQx0875b
# 4  3azJifCSqg9fRij2yKIbWz  spotify:track:3azJifCSqg9fRij2yKIbWz
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4h4QlmocP3Iu...
# 1  https://api.spotify.com/v1/tracks/3cBsEDNhFI9E...
# 2  https://api.spotify.com/v1/tracks/2BcMwX1MPV6Z...
# 3  https://api.spotify.com/v1/tracks/65OVbaJR5O1R...
# 4  https://api.spotify.com/v1/tracks/3azJifCSqg9f...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4h4Q...      163026
# 1  https://api.spotify.com/v1/audio-analysis/3cBs...      178520
# 2  https://api.spotify.com/v1/audio-analysis/2BcM...      242966
# 3  https://api.spotify.com/v1/audio-analysis/65OV...      192956
# 4  https://api.spotify.com/v1/audio-analysis/3azJ...      226467
#
#   time_signature
# 0              4
# 1              3
# 2              4
# 3              4
# 4              4

# %%
cols_to_drop2 = ['key', 'mode', 'type', 'uri', 'track_href', 'analysis_url']
tf_df = tf_df.drop(columns=cols_to_drop2)
print(track_df.info())
print(tf_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        1000 non-null   object
#  1   track_name         1000 non-null   object
#  2   track_id           1000 non-null   object
#  3   track_popularity   1000 non-null   int64
#  4   artist_id          1000 non-null   object
#  5   artist_popularity  1000 non-null   int64
#  6   artist_genres      1000 non-null   object
#  7   artist_followers   1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      996 non-null    float64
#  1   energy            996 non-null    float64
#  2   loudness          996 non-null    float64
#  3   speechiness       996 non-null    float64
#  4   acousticness      996 non-null    float64
#  5   instrumentalness  996 non-null    object
#  6   liveness          996 non-null    float64
#  7   valence           996 non-null    float64
#  8   tempo             996 non-null    float64
#  9   id                996 non-null    object
#  10  duration_ms       996 non-null    object
#  11  time_signature    996 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 93.5+ KB
# None

# %%
track_df['artist_name'] = track_df['artist_name'].astype("string")
track_df['track_name'] = track_df['track_name'].astype("string")
track_df['track_id'] = track_df['track_id'].astype("string")
track_df['artist_id'] = track_df['artist_id'].astype("string")
tf_df['duration_ms'] = pd.to_numeric(tf_df['duration_ms'])
tf_df['instrumentalness'] = pd.to_numeric(tf_df['instrumentalness'])
tf_df['time_signature'] = tf_df['time_signature'].astype("category")
print(track_df.info())
print(tf_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        1000 non-null   string
#  1   track_name         1000 non-null   string
#  2   track_id           1000 non-null   string
#  3   track_popularity   1000 non-null   int64
#  4   artist_id          1000 non-null   string
#  5   artist_popularity  1000 non-null   int64
#  6   artist_genres      1000 non-null   object
#  7   artist_followers   1000 non-null   int64
# dtypes: int64(3), object(1), string(4)
# memory usage: 62.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      996 non-null    float64
#  1   energy            996 non-null    float64
#  2   loudness          996 non-null    float64
#  3   speechiness       996 non-null    float64
#  4   acousticness      996 non-null    float64
#  5   instrumentalness  996 non-null    float64
#  6   liveness          996 non-null    float64
#  7   valence           996 non-null    float64
#  8   tempo             996 non-null    float64
#  9   id                996 non-null    object
#  10  duration_ms       996 non-null    int64
#  11  time_signature    996 non-null    category
# dtypes: category(1), float64(9), int64(1), object(1)
# memory usage: 86.9+ KB
# None

# %%
track_df.sort_values(by=['track_popularity'], ascending=False)[
    ['track_name', 'artist_name']].head(20)
# Out:
#                                             track_name       artist_name
# 0                                              Sunroof       Nicky Youre
# 5                                    Until I Found You   Stephen Sanchez
# 127                                  Where Are You Now  Lost Frequencies
# 41                                          Bad Habits        Ed Sheeran
# 7                                    Happier Than Ever     Billie Eilish
# 19                           STAY (with Justin Bieber)     The Kid LAROI
# 10                                             traitor    Olivia Rodrigo
# 11                                               Woman          Doja Cat
# 30                                             Shivers        Ed Sheeran
# 24                                     drivers license    Olivia Rodrigo
# 29                                            Yonaguni         Bad Bunny
# 14                                             deja vu    Olivia Rodrigo
# 22                                               Ghost     Justin Bieber
# 8                                             good 4 u    Olivia Rodrigo
# 59                             Cold Heart - PNAU Remix        Elton John
# 68                           STAY (with Justin Bieber)     The Kid LAROI
# 37   Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)             Tainy
# 62   Enemy (with JID) - from the series Arcane Leag...   Imagine Dragons
# 36                                   THATS WHAT I WANT         Lil Nas X
# 70                                               Pepas           Farruko

# %%
by_art_fol = pd.DataFrame(track_df.sort_values(by=['artist_followers'], ascending=False)[
                          ['artist_followers', 'artist_popularity', 'artist_name', 'artist_genres']])
by_art_fol.astype(str).drop_duplicates().head(20)
# Out:
#     artist_followers artist_popularity      artist_name  \
# 630        104500158                89       Ed Sheeran
# 834         84509960                87    Ariana Grande
# 570         71199028                87    Billie Eilish
# 83          68410744                95            Drake
# 787         67092153                89    Justin Bieber
# 152         61488932               100     Taylor Swift
# 592         61140486                90           Eminem
# 29          58442863                97        Bad Bunny
# 739         56814230                90              BTS
# 928         51913755                93       The Weeknd
# 433         44078045                86       Bruno Mars
# 147         43497575                83            Adele
# 62          43037927                87  Imagine Dragons
# 459         39717167                83     Shawn Mendes
# 229         39509610                87         Coldplay
# 117         38630222                87      Post Malone
# 82          38434290                84         Maroon 5
# 779         38202971                83     Selena Gomez
# 487         37003361                87         Dua Lipa
# 929         35683993                87         J Balvin
#
#                                          artist_genres
# 630                                  ['pop', 'uk pop']
# 834                               ['dance pop', 'pop']
# 570                   ['art pop', 'electropop', 'pop']
# 83   ['canadian hip hop', 'canadian pop', 'hip hop'...
# 787                            ['canadian pop', 'pop']
# 152                                            ['pop']
# 592              ['detroit hip hop', 'hip hop', 'rap']
# 29                        ['reggaeton', 'trap latino']
# 739                       ['k-pop', 'k-pop boy group']
# 928  ['canadian contemporary r&b', 'canadian pop', ...
# 433                               ['dance pop', 'pop']
# 147      ['british soul', 'pop', 'pop soul', 'uk pop']
# 62                             ['modern rock', 'rock']
# 459  ['canadian pop', 'dance pop', 'pop', 'viral pop']
# 229                          ['permanent wave', 'pop']
# 117                  ['dfw rap', 'melodic rap', 'rap']
# 82                                             ['pop']
# 779              ['dance pop', 'pop', 'post-teen pop']
# 487                     ['dance pop', 'pop', 'uk pop']
# 929  ['reggaeton', 'reggaeton colombiano', 'trap la...

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])


to_1D(track_df['artist_genres']).value_counts().head(20)
# Out:
# pop                      278
# rap                      187
# contemporary country      98
# trap                      86
# hip hop                   85
# country                   82
# dance pop                 70
# pop rap                   54
# nueva musica mexicana     51
# country road              48
# viral rap                 42
# sad sierreno              38
# southern hip hop          36
# canadian pop              35
# uk pop                    35
# corrido                   34
# electropop                34
# melodic rap               34
# musica mexicana           32
# canadian hip hop          31
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(14, 4))
ax.bar(to_1D(track_df['artist_genres']).value_counts().index[:10],
       to_1D(track_df['artist_genres']).value_counts().values[:10])
ax.set_ylabel("Frequency", size=12)
ax.set_title("Top genres", size=14)
# Out:
# Text(0.5, 1.0, 'Top genres')

# %%
top_10_genres = list(
    to_1D(track_df['artist_genres']).value_counts().index[:20])
top_artists_by_genre = []
for genre in top_10_genres:
    for index, row in by_art_fol.iterrows():
        if genre in row['artist_genres']:
            top_artists_by_genre.append(
                {'artist_name': row['artist_name'], 'artist_genre': genre})
            break
pd.json_normalize(top_artists_by_genre)
# Out:
#         artist_name           artist_genre
# 0        Ed Sheeran                    pop
# 1             Drake                    rap
# 2        Luke Bryan   contemporary country
# 3             Migos                   trap
# 4             Drake                hip hop
# 5        Luke Bryan                country
# 6     Ariana Grande              dance pop
# 7             Migos                pop rap
# 8   Christian Nodal  nueva musica mexicana
# 9        Luke Bryan           country road
# 10       NLE Choppa              viral rap
# 11    Virlan Garcia           sad sierreno
# 12        DJ Khaled       southern hip hop
# 13            Drake           canadian pop
# 14       Ed Sheeran                 uk pop
# 15    Gerardo Ortiz                corrido
# 16    Billie Eilish             electropop
# 17      Post Malone            melodic rap
# 18  Christian Nodal        musica mexicana
# 19            Drake       canadian hip hop

# %%
by_track_pop = pd.DataFrame(track_df.sort_values(by=['track_popularity'], ascending=False)[
                            ['track_popularity', 'track_name', 'artist_name', 'artist_genres', 'track_id']])
by_track_pop.astype(str).drop_duplicates().head(20)
top_songs_by_genre = []
for genre in top_10_genres:
    for index, row in by_track_pop.iterrows():
        if genre in row['artist_genres']:
            top_songs_by_genre.append(
                {'track_name': row['track_name'], 'track_popularity': row['track_popularity'], 'artist_name': row['artist_name'], 'artist_genre': genre})
            break
pd.json_normalize(top_songs_by_genre)
# Out:
#                                         track_name  track_popularity  \
# 0                                          Sunroof                90
# 1                                 The Color Violet                84
# 2                                    Wasted On You                82
# 3                                 The Color Violet                84
# 4      Knife Talk (with 21 Savage ft. Project Pat)                84
# 5                                    Wasted On You                82
# 6                                            Woman                87
# 7                                 The Color Violet                84
# 8                                   Fuga Pa Cali 2                80
# 9                                         Buy Dirt                79
# 10                                         Tell Em                79
# 11                                  Fuga Pa Cali 2                80
# 12  EVERY CHANCE I GET (feat. Lil Baby & Lil Durk)                77
# 13                                           Ghost                86
# 14                                      Bad Habits                87
# 15                                  Fuga Pa Cali 2                80
# 16                               Happier Than Ever                87
# 17                                The Color Violet                84
# 18                                  Fuga Pa Cali 2                80
# 19                                The Color Violet                84
#
#           artist_name           artist_genre
# 0         Nicky Youre                    pop
# 1          Tory Lanez                    rap
# 2       Morgan Wallen   contemporary country
# 3          Tory Lanez                   trap
# 4               Drake                hip hop
# 5       Morgan Wallen                country
# 6            Doja Cat              dance pop
# 7          Tory Lanez                pop rap
# 8   Grupo Los de la O  nueva musica mexicana
# 9        Jordan Davis           country road
# 10            Cochise              viral rap
# 11  Grupo Los de la O           sad sierreno
# 12          DJ Khaled       southern hip hop
# 13      Justin Bieber           canadian pop
# 14         Ed Sheeran                 uk pop
# 15  Grupo Los de la O                corrido
# 16      Billie Eilish             electropop
# 17         Tory Lanez            melodic rap
# 18  Grupo Los de la O        musica mexicana
# 19         Tory Lanez       canadian hip hop

# %%
import seaborn as sn
sn.set(rc={'figure.figsize': (12, 10)})
sn.heatmap(tf_df.corr(), annot=True)
plt.show()

# %%
sn.set(rc={'figure.figsize': (20, 20)})
sn.jointplot(data=tf_df, x="loudness", y="energy", kind="kde")

# %%
import plotly.offline as pyo
import plotly.graph_objects as go
from sklearn import preprocessing
feat_cols = ['danceability', 'energy', 'speechiness',
             'acousticness', 'instrumentalness', 'liveness', 'valence']
top_100_feat = pd.DataFrame(columns=feat_cols)
for i, track in by_track_pop[:100].iterrows():
    features = tf_df[tf_df['id'] == track['track_id']]
    top_100_feat = top_100_feat.append(features, ignore_index=True)
top_100_feat = top_100_feat[feat_cols]

mean_vals = pd.DataFrame(columns=feat_cols)
mean_vals = mean_vals.append(top_100_feat.mean(), ignore_index=True)
mean_vals = mean_vals.append(tf_df[feat_cols].mean(), ignore_index=True)
print(mean_vals)

fig = go.Figure(
    data=[
        go.Scatterpolar(
            r=mean_vals.iloc[0], theta=feat_cols, fill='toself', name='Top 100'),
        go.Scatterpolar(
            r=mean_vals.iloc[1], theta=feat_cols, fill='toself', name='All'),
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Feature comparison'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

# pyo.plot(fig)
fig.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\1716867484.py:9: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\1716867484.py:9: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\1716867484.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11168\1716867484.py:14: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#    danceability    energy  speechiness  acousticness  instrumentalness  \
# 0      0.665900  0.671380     0.080739      0.230319          0.061354
# 1      0.641638  0.612385     0.115866      0.264982          0.059057
#
#    liveness   valence
# 0  0.158263  0.488324
# 1  0.177840  0.488072

# %%
rec = sp.recommendations(seed_artists=["3PhoLpVuITZKcymswpck5b"], seed_genres=[
                         "pop"], seed_tracks=["1r9xUipOqoNwggBpENDsvJ"], limit=100)
for track in rec['tracks']:
    print(track['artists'][0]['name'], track['name'])
# Out:
# Post Malone I Fall Apart
# Badfinger Maybe Tomorrow - Remastered 2010
# David Guetta Dangerous (feat. Sam Martin)
# Maroon 5 Cold
# AJR Weak
# Galantis Runaway (U & I)
# Migos Bad and Boujee (feat. Lil Uzi Vert)
# Adam Jensen The Mystic
# DJ Khaled Shining (feat. Beyoncé & Jay-Z)
# Lost Frequencies Are You With Me - Radio Edit
# Trey Songz Slow Motion
# Van Morrison Streamline Train
# Clean Bandit Tears (feat. Louisa Johnson)
# Jackson Browne Stay - 2018 Remaster
# Anne Murray You Needed Me
# The Rolling Stones Doo Doo Doo Doo Doo (Heartbreaker)
# TheFatRat Warbringer
# Dermot Kennedy Kiss Me
# Little Mix Secret Love Song (feat. Jason Derulo)
# Joshua Micah Let The Light In
# Shawn Mendes Never Be Alone / Hey There Delilah - Live Medley
# Chris Rea Gone Fishing
# ABBA Ode To Freedom
# Coldplay Hymn for the Weekend - Seeb Remix
# Club Report Love Grows (In Rosemary's Disco)
# Jessie J Bang Bang
# Imagine Dragons I Don't Mind
# Jason Derulo Trumpets
# Avicii Without You (feat. Sandro Cavazza)
# Ronan Keating The Blower's Daughter
# Elton John This Train Don't Stop There Anymore
# The Beatles One After 909 - Rooftop Performance
# Twenty One Pilots Migraine
# Pitbull Time of Our Lives
# League of Legends Worlds Collide
# Avicii Hey Brother
# Sia Unstoppable - Clarence Clarity Remix
# Snakehips Either Way (feat. Joey Bada$$)
# Christine McVie Songbird - Orchestral Version
# AJR Weak
# Stevie Nicks For What It's Worth
# Fifth Harmony Down (feat. Gucci Mane)
# Vicetone My Heart’s on Fire
# Skillet Hero
# Ava Max Maybe You’re The Problem
# Smokie Arms of Mary
# Ed Sheeran Shape of You
# Elton John Medley: Yell Help / Wednesday Night / Ugly
# Shania Twain Waking Up Dreaming
# Adam Jensen Bad Day for My Enemies
# Panic! At The Disco This Is Gospel
# Imagine Dragons Walking The Wire
# Mac Miller My Favorite Part
# David Guetta I'm Good (Blue) - R3HAB Remix
# Ed Sheeran Galway Girl
# Twenty One Pilots Stressed Out
# Imagine Dragons Younger
# Coldplay Higher Power
# ZAYN I Don’t Wanna Live Forever (Fifty Shades Darker)
# Halsey Now Or Never
# Yuna Crush
# David Guetta I'm Good (Blue) - Tiësto Remix
# Migos Fight Night
# Mike WiLL Made-It Nothing Is Promised (with Rihanna)
# Lady Gaga Bad Romance
# Omarion Post to Be (feat. Chris Brown & Jhene Aiko)
# Chris Brown Loyal
# Rag'n'Bone Man Skin
# Lewis Capaldi Forget Me
# The Chainsmokers Who Do You Love
# Måneskin Beggin'
# Bruno Mars Finesse - Remix; feat. Cardi B
# David Bowie Space Oddity - Moonage Daydream Mix
# Dynoro In My Mind
# Maroon 5 What Lovers Do (feat. SZA)
# Electric Light Orchestra Hold On Tight
# ABBA Dancing Queen
# Christopher Cross Ride Like the Wind - Joey Negro Extended Disco Mix
# Jax Jones You Don't Know Me
# Chris Brown New Flame
# Bryson Tiller Don't
# Chris Rea Fool (If You Think It's Over)
# Elton John We All Fall In Love Sometimes
# Kiiara Whippin (feat. Felix Snow)
# Avicii Waiting For Love
# LEC Awakened
# Coldplay Something Just Like This - Tokyo Remix
# Santiano Santiano - Jerome Remix
# The Chainsmokers Sick Boy
# Sheppard Geronimo - D-wayne Remix
# The Beatles I've Got A Feeling - Rooftop Performance / Take 1
# Selena Gomez Back To You - From 13 Reasons Why – Season 2 Soundtrack
# Cheat Codes Only You (with Little Mix)
# ScHoolboy Q Studio
# Miley Cyrus We Can't Stop
# Troye Sivan Dance To This (feat. Ariana Grande)
# The 1975 Girls
# MEAU Dans M'n Ogen Dicht
# Katy Perry Unconditionally
# Charli XCX 1999
